# %% [markdown]
# Generate synthetic audio (random frequency and amplitude)

# %%
import os
import numpy as np
from scipy.io.wavfile import write
from scipy.signal import sawtooth, square

# Audio properties
sample_rate = 8000  # Hz
duration = 2  # seconds
num_samples = sample_rate * duration

# Directory to save files
output_dir = "synthetic_audio"
classes = ['circle', 'heart', 'hexagon', 'square', 'star', 'triangle']

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)


def generate_heart_wave(freq, amp, num_samples, sample_rate):
    """Amplitude modulated wave."""
    t = np.linspace(0, duration, num_samples, endpoint=False)
    carrier = np.sin(2 * np.pi * freq * t)
    modulator = 0.5 * (1 + np.sin(2 * np.pi * freq / 4 * t))  # Slow modulator
    return amp * carrier * modulator

def generate_hexagon_wave(freq, amp, num_samples, sample_rate):
    """Frequency modulated wave."""
    t = np.linspace(0, duration, num_samples, endpoint=False)
    mod_freq = freq / 2  # Modulation frequency
    mod = np.sin(2 * np.pi * mod_freq * t)
    return amp * np.sin(2 * np.pi * freq * t + mod)

def generate_square_wave(freq, amp, num_samples, sample_rate):
    """Square wave."""
    t = np.linspace(0, duration, num_samples, endpoint=False)
    return amp * square(2 * np.pi * freq * t)

def generate_star_wave(freq, amp, num_samples, sample_rate):
    """Sawtooth wave."""
    t = np.linspace(0, duration, num_samples, endpoint=False)
    return amp * sawtooth(2 * np.pi * freq * t)

def generate_circle_wave(freq, amp, num_samples, sample_rate):
    """Smooth oscillation: 'weeeeeeoo-weeeeeeoo'."""
    t = np.linspace(0, duration, num_samples, endpoint=False)
    mod_freq = 2  # Modulation frequency (oscillations per second)
    mod = np.sin(2 * np.pi * mod_freq * t)  # Smooth oscillation pattern
    carrier = np.sin(2 * np.pi * freq * (1 + 0.5 * mod) * t)  # Modulate the carrier
    return amp * carrier

def generate_triangle_wave(freq, amp, num_samples, sample_rate):
    """Stepped descending tone: 'weeeeeeeoooo...weeeeeeeoooo...'."""
    t = np.linspace(0, duration, num_samples, endpoint=False)
    stepped_freq = np.piecewise(
        t,
        [t < 0.5, (t >= 0.5) & (t < 1.0), (t >= 1.0) & (t < 1.5), t >= 1.5],
        [freq, freq * 0.75, freq * 0.5, freq * 0.25]
    )  # Step down frequency every 0.5 seconds
    return amp * np.sin(2 * np.pi * stepped_freq * t)


# Generate and save audio clips
wave_generators = {
    'circle': generate_circle_wave,
    'heart': generate_heart_wave,
    'hexagon': generate_hexagon_wave,
    'square': generate_square_wave,
    'star': generate_star_wave,
    'triangle': generate_triangle_wave
}

for class_name in classes:
    class_dir = os.path.join(output_dir, class_name)
    os.makedirs(class_dir, exist_ok=True)

    for i in range(1, 201):
        # Generate random frequency and amplitude for variability
        freq = np.random.uniform(200, 800)  # Frequency between 200Hz and 800Hz
        amp = np.random.uniform(0.3, 0.9)  # Amplitude between 0.3 and 0.9

        # Generate waveform
        waveform = wave_generators[class_name](freq, amp, num_samples, sample_rate)

        # Add random noise to make each clip unique
        noise = np.random.normal(0, 0.02, num_samples)  # Small Gaussian noise
        waveform = np.clip(waveform + noise, -1.0, 1.0)  # Ensure values are within [-1, 1]

        # Save to file
        file_name = f"clip_{i:03d}.wav"
        file_path = os.path.join(class_dir, file_name)
# Saved: synthetic_audio/circle/clip_193.wav
# Saved: synthetic_audio/circle/clip_194.wav
# Saved: synthetic_audio/circle/clip_195.wav
# Saved: synthetic_audio/circle/clip_196.wav
# Saved: synthetic_audio/circle/clip_197.wav
# Saved: synthetic_audio/circle/clip_198.wav
# Saved: synthetic_audio/circle/clip_199.wav
# Saved: synthetic_audio/circle/clip_200.wav
# Saved: synthetic_audio/heart/clip_001.wav
# Saved: synthetic_audio/heart/clip_002.wav
# Saved: synthetic_audio/heart/clip_003.wav
# Saved: synthetic_audio/heart/clip_004.wav
# Saved: synthetic_audio/heart/clip_005.wav
# Saved: synthetic_audio/heart/clip_006.wav
# Saved: synthetic_audio/heart/clip_007.wav
# Saved: synthetic_audio/heart/clip_008.wav
# Saved: synthetic_audio/heart/clip_009.wav
# Saved: synthetic_audio/heart/clip_010.wav
# Saved: synthetic_audio/heart/clip_011.wav
# Saved: synthetic_audio/heart/clip_012.wav
# Saved: synthetic_audio/heart/clip_013.wav
# Saved: synthetic_audio/heart/clip_014.wav
# Saved: synthetic_audio/heart/clip_015.wav
# Saved: synthetic_audio/heart/clip_016.wav
# Saved: synthetic_audio/heart/clip_017.wav
# Saved: synthetic_audio/heart/clip_018.wav
# Saved: synthetic_audio/heart/clip_019.wav
# Saved: synthetic_audio/heart/clip_020.wav
# Saved: synthetic_audio/heart/clip_021.wav
# Saved: synthetic_audio/heart/clip_022.wav
# Saved: synthetic_audio/heart/clip_023.wav
# Saved: synthetic_audio/heart/clip_024.wav
# Saved: synthetic_audio/heart/clip_025.wav
# Saved: synthetic_audio/heart/clip_026.wav
# Saved: synthetic_audio/heart/clip_027.wav
# Saved: synthetic_audio/heart/clip_028.wav
# Saved: synthetic_audio/heart/clip_029.wav
# Saved: synthetic_audio/heart/clip_030.wav
# Saved: synthetic_audio/heart/clip_031.wav
# Saved: synthetic_audio/heart/clip_032.wav
# Saved: synthetic_audio/heart/clip_033.wav
# Saved: synthetic_audio/heart/clip_034.wav
# Saved: synthetic_audio/heart/clip_035.wav
# Saved: synthetic_audio/heart/clip_036.wav
# Saved: synthetic_audio/heart/clip_037.wav
# Saved: synthetic_audio/heart/clip_038.wav
# Saved: synthetic_audio/heart/clip_039.wav
# Saved: synthetic_audio/heart/clip_040.wav
# Saved: synthetic_audio/heart/clip_041.wav
# Saved: synthetic_audio/heart/clip_042.wav
# Saved: synthetic_audio/heart/clip_043.wav
# Saved: synthetic_audio/heart/clip_044.wav
# Saved: synthetic_audio/heart/clip_045.wav
# Saved: synthetic_audio/heart/clip_046.wav
# Saved: synthetic_audio/heart/clip_047.wav
# Saved: synthetic_audio/heart/clip_048.wav
# Saved: synthetic_audio/heart/clip_049.wav
# Saved: synthetic_audio/heart/clip_050.wav
# Saved: synthetic_audio/heart/clip_051.wav
# Saved: synthetic_audio/heart/clip_052.wav
# Saved: synthetic_audio/heart/clip_053.wav
# Saved: synthetic_audio/heart/clip_054.wav
# Saved: synthetic_audio/heart/clip_055.wav
# Saved: synthetic_audio/heart/clip_056.wav
# Saved: synthetic_audio/heart/clip_057.wav
# Saved: synthetic_audio/heart/clip_058.wav
# Saved: synthetic_audio/heart/clip_059.wav
# Saved: synthetic_audio/heart/clip_060.wav
# Saved: synthetic_audio/heart/clip_061.wav
# Saved: synthetic_audio/heart/clip_062.wav
# Saved: synthetic_audio/heart/clip_063.wav
# Saved: synthetic_audio/heart/clip_064.wav
# Saved: synthetic_audio/heart/clip_065.wav
# Saved: synthetic_audio/heart/clip_066.wav
# Saved: synthetic_audio/heart/clip_067.wav
# Saved: synthetic_audio/heart/clip_068.wav
# Saved: synthetic_audio/heart/clip_069.wav
# Saved: synthetic_audio/heart/clip_070.wav
# Saved: synthetic_audio/heart/clip_071.wav
# Saved: synthetic_audio/heart/clip_072.wav
# Saved: synthetic_audio/heart/clip_073.wav
# Saved: synthetic_audio/heart/clip_074.wav
# Saved: synthetic_audio/heart/clip_075.wav
# Saved: synthetic_audio/heart/clip_076.wav
# Saved: synthetic_audio/heart/clip_077.wav
# Saved: synthetic_audio/heart/clip_078.wav
# Saved: synthetic_audio/heart/clip_079.wav
# Saved: synthetic_audio/heart/clip_080.wav
# Saved: synthetic_audio/heart/clip_081.wav
# Saved: synthetic_audio/heart/clip_082.wav
# Saved: synthetic_audio/heart/clip_083.wav
# Saved: synthetic_audio/heart/clip_084.wav
# Saved: synthetic_audio/heart/clip_085.wav
# Saved: synthetic_audio/heart/clip_086.wav
# Saved: synthetic_audio/heart/clip_087.wav
# Saved: synthetic_audio/heart/clip_088.wav
# Saved: synthetic_audio/heart/clip_089.wav
# Saved: synthetic_audio/heart/clip_090.wav
# Saved: synthetic_audio/heart/clip_091.wav
# Saved: synthetic_audio/heart/clip_092.wav
# Saved: synthetic_audio/heart/clip_093.wav
# Saved: synthetic_audio/heart/clip_094.wav
# Saved: synthetic_audio/heart/clip_095.wav
# Saved: synthetic_audio/heart/clip_096.wav
# Saved: synthetic_audio/heart/clip_097.wav
# Saved: synthetic_audio/heart/clip_098.wav
# Saved: synthetic_audio/heart/clip_099.wav
# Saved: synthetic_audio/heart/clip_100.wav
# Saved: synthetic_audio/heart/clip_101.wav
# Saved: synthetic_audio/heart/clip_102.wav
# Saved: synthetic_audio/heart/clip_103.wav
# Saved: synthetic_audio/heart/clip_104.wav
# Saved: synthetic_audio/heart/clip_105.wav
# Saved: synthetic_audio/heart/clip_106.wav
# Saved: synthetic_audio/heart/clip_107.wav
# Saved: synthetic_audio/heart/clip_108.wav
# Saved: synthetic_audio/heart/clip_109.wav
# Saved: synthetic_audio/heart/clip_110.wav
# Saved: synthetic_audio/heart/clip_111.wav
# Saved: synthetic_audio/heart/clip_112.wav
# Saved: synthetic_audio/heart/clip_113.wav
# Saved: synthetic_audio/heart/clip_114.wav
# Saved: synthetic_audio/heart/clip_115.wav
# Saved: synthetic_audio/heart/clip_116.wav
# Saved: synthetic_audio/heart/clip_117.wav
# Saved: synthetic_audio/heart/clip_118.wav
# Saved: synthetic_audio/heart/clip_119.wav
# Saved: synthetic_audio/heart/clip_120.wav
# Saved: synthetic_audio/heart/clip_121.wav
# Saved: synthetic_audio/heart/clip_122.wav
# Saved: synthetic_audio/heart/clip_123.wav
# Saved: synthetic_audio/heart/clip_124.wav
# Saved: synthetic_audio/heart/clip_125.wav
# Saved: synthetic_audio/heart/clip_126.wav
# Saved: synthetic_audio/heart/clip_127.wav
# Saved: synthetic_audio/heart/clip_128.wav
# Saved: synthetic_audio/heart/clip_129.wav
# Saved: synthetic_audio/heart/clip_130.wav
# Saved: synthetic_audio/heart/clip_131.wav
# Saved: synthetic_audio/heart/clip_132.wav
# Saved: synthetic_audio/heart/clip_133.wav
# Saved: synthetic_audio/heart/clip_134.wav
# Saved: synthetic_audio/heart/clip_135.wav
# Saved: synthetic_audio/heart/clip_136.wav
# Saved: synthetic_audio/heart/clip_137.wav
# Saved: synthetic_audio/heart/clip_138.wav
# Saved: synthetic_audio/heart/clip_139.wav
# Saved: synthetic_audio/heart/clip_140.wav
# Saved: synthetic_audio/heart/clip_141.wav
# Saved: synthetic_audio/heart/clip_142.wav
# Saved: synthetic_audio/heart/clip_143.wav
# Saved: synthetic_audio/heart/clip_144.wav
# Saved: synthetic_audio/heart/clip_145.wav
# Saved: synthetic_audio/heart/clip_146.wav
# Saved: synthetic_audio/heart/clip_147.wav
# Saved: synthetic_audio/heart/clip_148.wav
# Saved: synthetic_audio/heart/clip_149.wav
# Saved: synthetic_audio/heart/clip_150.wav
# Saved: synthetic_audio/heart/clip_151.wav
# Saved: synthetic_audio/heart/clip_152.wav
# Saved: synthetic_audio/heart/clip_153.wav
# Saved: synthetic_audio/heart/clip_154.wav
# Saved: synthetic_audio/heart/clip_155.wav
# Saved: synthetic_audio/heart/clip_156.wav
# Saved: synthetic_audio/heart/clip_157.wav
# Saved: synthetic_audio/heart/clip_158.wav
# Saved: synthetic_audio/heart/clip_159.wav
# Saved: synthetic_audio/heart/clip_160.wav
# Saved: synthetic_audio/heart/clip_161.wav
# Saved: synthetic_audio/heart/clip_162.wav
# Saved: synthetic_audio/heart/clip_163.wav
# Saved: synthetic_audio/heart/clip_164.wav
# Saved: synthetic_audio/heart/clip_165.wav
# Saved: synthetic_audio/heart/clip_166.wav
# Saved: synthetic_audio/heart/clip_167.wav
# Saved: synthetic_audio/heart/clip_168.wav
# Saved: synthetic_audio/heart/clip_169.wav
# Saved: synthetic_audio/heart/clip_170.wav
# Saved: synthetic_audio/heart/clip_171.wav
# Saved: synthetic_audio/heart/clip_172.wav
# Saved: synthetic_audio/heart/clip_173.wav
# Saved: synthetic_audio/heart/clip_174.wav
# Saved: synthetic_audio/heart/clip_175.wav
# Saved: synthetic_audio/heart/clip_176.wav
# Saved: synthetic_audio/heart/clip_177.wav
# Saved: synthetic_audio/heart/clip_178.wav
# Saved: synthetic_audio/heart/clip_179.wav
# Saved: synthetic_audio/heart/clip_180.wav
# Saved: synthetic_audio/heart/clip_181.wav
# Saved: synthetic_audio/heart/clip_182.wav
# Saved: synthetic_audio/heart/clip_183.wav
# Saved: synthetic_audio/heart/clip_184.wav
# Saved: synthetic_audio/heart/clip_185.wav
# Saved: synthetic_audio/heart/clip_186.wav
# Saved: synthetic_audio/heart/clip_187.wav
# Saved: synthetic_audio/heart/clip_188.wav
# Saved: synthetic_audio/heart/clip_189.wav
# Saved: synthetic_audio/heart/clip_190.wav
# Saved: synthetic_audio/heart/clip_191.wav
# Saved: synthetic_audio/heart/clip_192.wav
# Saved: synthetic_audio/heart/clip_193.wav
# Saved: synthetic_audio/heart/clip_194.wav
# Saved: synthetic_audio/heart/clip_195.wav
# Saved: synthetic_audio/heart/clip_196.wav
# Saved: synthetic_audio/heart/clip_197.wav
# Saved: synthetic_audio/heart/clip_198.wav
# Saved: synthetic_audio/heart/clip_199.wav
# Saved: synthetic_audio/heart/clip_200.wav
# Saved: synthetic_audio/hexagon/clip_001.wav
# Saved: synthetic_audio/hexagon/clip_002.wav
# Saved: synthetic_audio/hexagon/clip_003.wav
# Saved: synthetic_audio/hexagon/clip_004.wav
# Saved: synthetic_audio/hexagon/clip_005.wav
# Saved: synthetic_audio/hexagon/clip_006.wav
# Saved: synthetic_audio/hexagon/clip_007.wav
# Saved: synthetic_audio/hexagon/clip_008.wav
# Saved: synthetic_audio/hexagon/clip_009.wav
# Saved: synthetic_audio/hexagon/clip_010.wav
# Saved: synthetic_audio/hexagon/clip_011.wav
# Saved: synthetic_audio/hexagon/clip_012.wav
# Saved: synthetic_audio/hexagon/clip_013.wav
# Saved: synthetic_audio/hexagon/clip_014.wav
# Saved: synthetic_audio/hexagon/clip_015.wav
# Saved: synthetic_audio/hexagon/clip_016.wav
# Saved: synthetic_audio/hexagon/clip_017.wav
# Saved: synthetic_audio/hexagon/clip_018.wav
# Saved: synthetic_audio/hexagon/clip_019.wav
# Saved: synthetic_audio/hexagon/clip_020.wav
# Saved: synthetic_audio/hexagon/clip_021.wav
# Saved: synthetic_audio/hexagon/clip_022.wav
# Saved: synthetic_audio/hexagon/clip_023.wav
# Saved: synthetic_audio/hexagon/clip_024.wav
# Saved: synthetic_audio/hexagon/clip_025.wav
# Saved: synthetic_audio/hexagon/clip_026.wav
# Saved: synthetic_audio/hexagon/clip_027.wav
# Saved: synthetic_audio/hexagon/clip_028.wav
# Saved: synthetic_audio/hexagon/clip_029.wav
# Saved: synthetic_audio/hexagon/clip_030.wav
# Saved: synthetic_audio/hexagon/clip_031.wav
# Saved: synthetic_audio/hexagon/clip_032.wav
# Saved: synthetic_audio/hexagon/clip_033.wav
# Saved: synthetic_audio/hexagon/clip_034.wav
# Saved: synthetic_audio/hexagon/clip_035.wav
# Saved: synthetic_audio/hexagon/clip_036.wav
# Saved: synthetic_audio/hexagon/clip_037.wav
# Saved: synthetic_audio/hexagon/clip_038.wav
# Saved: synthetic_audio/hexagon/clip_039.wav
# Saved: synthetic_audio/hexagon/clip_040.wav
# Saved: synthetic_audio/hexagon/clip_041.wav
# Saved: synthetic_audio/hexagon/clip_042.wav
# Saved: synthetic_audio/hexagon/clip_043.wav
# Saved: synthetic_audio/hexagon/clip_044.wav
# Saved: synthetic_audio/hexagon/clip_045.wav
# Saved: synthetic_audio/hexagon/clip_046.wav
# Saved: synthetic_audio/hexagon/clip_047.wav
# Saved: synthetic_audio/hexagon/clip_048.wav
# Saved: synthetic_audio/hexagon/clip_049.wav
# Saved: synthetic_audio/hexagon/clip_050.wav
# Saved: synthetic_audio/hexagon/clip_051.wav
# Saved: synthetic_audio/hexagon/clip_052.wav
# Saved: synthetic_audio/hexagon/clip_053.wav
# Saved: synthetic_audio/hexagon/clip_054.wav
# Saved: synthetic_audio/hexagon/clip_055.wav
# Saved: synthetic_audio/hexagon/clip_056.wav
# Saved: synthetic_audio/hexagon/clip_057.wav
# Saved: synthetic_audio/hexagon/clip_058.wav
# Saved: synthetic_audio/hexagon/clip_059.wav
# Saved: synthetic_audio/hexagon/clip_060.wav
# Saved: synthetic_audio/hexagon/clip_061.wav
# Saved: synthetic_audio/hexagon/clip_062.wav
# Saved: synthetic_audio/hexagon/clip_063.wav
# Saved: synthetic_audio/hexagon/clip_064.wav
# Saved: synthetic_audio/hexagon/clip_065.wav
# Saved: synthetic_audio/hexagon/clip_066.wav
# Saved: synthetic_audio/hexagon/clip_067.wav
# Saved: synthetic_audio/hexagon/clip_068.wav
# Saved: synthetic_audio/hexagon/clip_069.wav
# Saved: synthetic_audio/hexagon/clip_070.wav
# Saved: synthetic_audio/hexagon/clip_071.wav
# Saved: synthetic_audio/hexagon/clip_072.wav
# Saved: synthetic_audio/hexagon/clip_073.wav
# Saved: synthetic_audio/hexagon/clip_074.wav
# Saved: synthetic_audio/hexagon/clip_075.wav
# Saved: synthetic_audio/hexagon/clip_076.wav
# Saved: synthetic_audio/hexagon/clip_077.wav
# Saved: synthetic_audio/hexagon/clip_078.wav
# Saved: synthetic_audio/hexagon/clip_079.wav
# Saved: synthetic_audio/hexagon/clip_080.wav
# Saved: synthetic_audio/hexagon/clip_081.wav
# Saved: synthetic_audio/hexagon/clip_082.wav
# Saved: synthetic_audio/hexagon/clip_083.wav
# Saved: synthetic_audio/hexagon/clip_084.wav
# Saved: synthetic_audio/hexagon/clip_085.wav
# Saved: synthetic_audio/hexagon/clip_086.wav
# Saved: synthetic_audio/hexagon/clip_087.wav
# Saved: synthetic_audio/hexagon/clip_088.wav
# Saved: synthetic_audio/hexagon/clip_089.wav
# Saved: synthetic_audio/hexagon/clip_090.wav
# Saved: synthetic_audio/hexagon/clip_091.wav
# Saved: synthetic_audio/hexagon/clip_092.wav
# Saved: synthetic_audio/hexagon/clip_093.wav
# Saved: synthetic_audio/hexagon/clip_094.wav
# Saved: synthetic_audio/hexagon/clip_095.wav
# Saved: synthetic_audio/hexagon/clip_096.wav
# Saved: synthetic_audio/hexagon/clip_097.wav
# Saved: synthetic_audio/hexagon/clip_098.wav
# Saved: synthetic_audio/hexagon/clip_099.wav
# Saved: synthetic_audio/hexagon/clip_100.wav
# Saved: synthetic_audio/hexagon/clip_101.wav
# Saved: synthetic_audio/hexagon/clip_102.wav
# Saved: synthetic_audio/hexagon/clip_103.wav
# Saved: synthetic_audio/hexagon/clip_104.wav
# Saved: synthetic_audio/hexagon/clip_105.wav
# Saved: synthetic_audio/hexagon/clip_106.wav
# Saved: synthetic_audio/hexagon/clip_107.wav
# Saved: synthetic_audio/hexagon/clip_108.wav
# Saved: synthetic_audio/square/clip_169.wav
# Saved: synthetic_audio/square/clip_170.wav
# Saved: synthetic_audio/square/clip_171.wav
# Saved: synthetic_audio/square/clip_172.wav
# Saved: synthetic_audio/square/clip_173.wav
# Saved: synthetic_audio/square/clip_174.wav
# Saved: synthetic_audio/square/clip_175.wav
# Saved: synthetic_audio/square/clip_176.wav
# Saved: synthetic_audio/square/clip_177.wav
# Saved: synthetic_audio/square/clip_178.wav
# Saved: synthetic_audio/square/clip_179.wav
# Saved: synthetic_audio/square/clip_180.wav
# Saved: synthetic_audio/square/clip_181.wav
# Saved: synthetic_audio/square/clip_182.wav
# Saved: synthetic_audio/square/clip_183.wav
# Saved: synthetic_audio/square/clip_184.wav
# Saved: synthetic_audio/square/clip_185.wav
# Saved: synthetic_audio/square/clip_186.wav
# Saved: synthetic_audio/square/clip_187.wav
# Saved: synthetic_audio/square/clip_188.wav
# Saved: synthetic_audio/square/clip_189.wav
# Saved: synthetic_audio/square/clip_190.wav
# Saved: synthetic_audio/square/clip_191.wav
# Saved: synthetic_audio/square/clip_192.wav
# Saved: synthetic_audio/square/clip_193.wav
# Saved: synthetic_audio/square/clip_194.wav
# Saved: synthetic_audio/square/clip_195.wav
# Saved: synthetic_audio/square/clip_196.wav
# Saved: synthetic_audio/square/clip_197.wav
# Saved: synthetic_audio/square/clip_198.wav
# Saved: synthetic_audio/square/clip_199.wav
# Saved: synthetic_audio/square/clip_200.wav
# Saved: synthetic_audio/star/clip_001.wav
# Saved: synthetic_audio/star/clip_002.wav
# Saved: synthetic_audio/star/clip_003.wav
# Saved: synthetic_audio/star/clip_004.wav
# Saved: synthetic_audio/star/clip_005.wav
# Saved: synthetic_audio/star/clip_006.wav
# Saved: synthetic_audio/star/clip_007.wav
# Saved: synthetic_audio/star/clip_008.wav
# Saved: synthetic_audio/star/clip_009.wav
# Saved: synthetic_audio/star/clip_010.wav
# Saved: synthetic_audio/star/clip_011.wav
# Saved: synthetic_audio/star/clip_012.wav
# Saved: synthetic_audio/star/clip_013.wav
# Saved: synthetic_audio/star/clip_014.wav
# Saved: synthetic_audio/star/clip_015.wav
# Saved: synthetic_audio/star/clip_016.wav
# Saved: synthetic_audio/star/clip_017.wav
# Saved: synthetic_audio/star/clip_018.wav
# Saved: synthetic_audio/star/clip_019.wav
# Saved: synthetic_audio/star/clip_020.wav
# Saved: synthetic_audio/star/clip_021.wav
# Saved: synthetic_audio/star/clip_022.wav
# Saved: synthetic_audio/star/clip_023.wav
# Saved: synthetic_audio/star/clip_024.wav
# Saved: synthetic_audio/star/clip_025.wav
# Saved: synthetic_audio/star/clip_026.wav
# Saved: synthetic_audio/star/clip_027.wav
# Saved: synthetic_audio/star/clip_028.wav
# Saved: synthetic_audio/star/clip_029.wav
# Saved: synthetic_audio/star/clip_030.wav
# Saved: synthetic_audio/star/clip_031.wav
# Saved: synthetic_audio/star/clip_032.wav
# Saved: synthetic_audio/star/clip_033.wav
# Saved: synthetic_audio/star/clip_034.wav
# Saved: synthetic_audio/star/clip_035.wav
# Saved: synthetic_audio/star/clip_036.wav
# Saved: synthetic_audio/star/clip_037.wav
# Saved: synthetic_audio/star/clip_038.wav
# Saved: synthetic_audio/star/clip_039.wav
# Saved: synthetic_audio/star/clip_040.wav
# Saved: synthetic_audio/star/clip_041.wav
# Saved: synthetic_audio/star/clip_042.wav
# Saved: synthetic_audio/star/clip_043.wav
# Saved: synthetic_audio/star/clip_044.wav
# Saved: synthetic_audio/star/clip_045.wav
# Saved: synthetic_audio/star/clip_046.wav
# Saved: synthetic_audio/star/clip_047.wav
# Saved: synthetic_audio/star/clip_048.wav
# Saved: synthetic_audio/star/clip_049.wav
# Saved: synthetic_audio/star/clip_050.wav
# Saved: synthetic_audio/star/clip_051.wav
# Saved: synthetic_audio/star/clip_052.wav
# Saved: synthetic_audio/star/clip_053.wav
# Saved: synthetic_audio/star/clip_054.wav
# Saved: synthetic_audio/star/clip_055.wav
# Saved: synthetic_audio/star/clip_056.wav
# Saved: synthetic_audio/star/clip_057.wav
# Saved: synthetic_audio/star/clip_058.wav
# Saved: synthetic_audio/star/clip_059.wav
# Saved: synthetic_audio/star/clip_060.wav
# Saved: synthetic_audio/star/clip_061.wav
# Saved: synthetic_audio/star/clip_062.wav
# Saved: synthetic_audio/star/clip_063.wav
# Saved: synthetic_audio/star/clip_064.wav
# Saved: synthetic_audio/star/clip_065.wav
# Saved: synthetic_audio/star/clip_066.wav
# Saved: synthetic_audio/star/clip_067.wav
# Saved: synthetic_audio/star/clip_068.wav
# Saved: synthetic_audio/star/clip_069.wav
# Saved: synthetic_audio/star/clip_070.wav
# Saved: synthetic_audio/star/clip_071.wav
# Saved: synthetic_audio/star/clip_072.wav
# Saved: synthetic_audio/star/clip_073.wav
# Saved: synthetic_audio/star/clip_074.wav
# Saved: synthetic_audio/star/clip_075.wav
# Saved: synthetic_audio/star/clip_076.wav
# Saved: synthetic_audio/star/clip_077.wav
# Saved: synthetic_audio/star/clip_078.wav
# Saved: synthetic_audio/star/clip_079.wav
# Saved: synthetic_audio/star/clip_080.wav
# Saved: synthetic_audio/star/clip_081.wav
# Saved: synthetic_audio/star/clip_082.wav
# Saved: synthetic_audio/star/clip_083.wav
# Saved: synthetic_audio/star/clip_084.wav
# Saved: synthetic_audio/star/clip_085.wav
# Saved: synthetic_audio/star/clip_086.wav
# Saved: synthetic_audio/star/clip_087.wav
# Saved: synthetic_audio/star/clip_088.wav
# Saved: synthetic_audio/star/clip_089.wav
# Saved: synthetic_audio/star/clip_090.wav
# Saved: synthetic_audio/star/clip_091.wav
# Saved: synthetic_audio/star/clip_092.wav
# Saved: synthetic_audio/star/clip_093.wav
# Saved: synthetic_audio/star/clip_094.wav
# Saved: synthetic_audio/star/clip_095.wav
# Saved: synthetic_audio/star/clip_096.wav
# Saved: synthetic_audio/star/clip_097.wav
# Saved: synthetic_audio/star/clip_098.wav
# Saved: synthetic_audio/star/clip_099.wav
# Saved: synthetic_audio/star/clip_100.wav
# Saved: synthetic_audio/star/clip_101.wav
# Saved: synthetic_audio/star/clip_102.wav
# Saved: synthetic_audio/star/clip_103.wav
# Saved: synthetic_audio/star/clip_104.wav
# Saved: synthetic_audio/star/clip_105.wav
# Saved: synthetic_audio/star/clip_106.wav
# Saved: synthetic_audio/star/clip_107.wav
# Saved: synthetic_audio/star/clip_108.wav
# Saved: synthetic_audio/star/clip_109.wav
# Saved: synthetic_audio/star/clip_110.wav
# Saved: synthetic_audio/star/clip_111.wav
# Saved: synthetic_audio/star/clip_112.wav
# Saved: synthetic_audio/star/clip_113.wav
# Saved: synthetic_audio/star/clip_114.wav
# Saved: synthetic_audio/star/clip_115.wav
# Saved: synthetic_audio/star/clip_116.wav
# Saved: synthetic_audio/star/clip_117.wav
# Saved: synthetic_audio/star/clip_118.wav
# Saved: synthetic_audio/star/clip_119.wav
# Saved: synthetic_audio/star/clip_120.wav
# Saved: synthetic_audio/star/clip_121.wav
# Saved: synthetic_audio/star/clip_122.wav
# Saved: synthetic_audio/star/clip_123.wav
# Saved: synthetic_audio/star/clip_124.wav
# Saved: synthetic_audio/star/clip_125.wav
# Saved: synthetic_audio/star/clip_126.wav
# Saved: synthetic_audio/star/clip_127.wav
# Saved: synthetic_audio/star/clip_128.wav
# Saved: synthetic_audio/star/clip_129.wav
# Saved: synthetic_audio/star/clip_130.wav
# Saved: synthetic_audio/star/clip_131.wav
# Saved: synthetic_audio/star/clip_132.wav
# Saved: synthetic_audio/star/clip_133.wav
# Saved: synthetic_audio/star/clip_134.wav
# Saved: synthetic_audio/star/clip_135.wav
# Saved: synthetic_audio/star/clip_136.wav
# Saved: synthetic_audio/star/clip_137.wav
# Saved: synthetic_audio/star/clip_138.wav
# Saved: synthetic_audio/star/clip_139.wav
# Saved: synthetic_audio/star/clip_140.wav
# Saved: synthetic_audio/star/clip_141.wav
# Saved: synthetic_audio/star/clip_142.wav
# Saved: synthetic_audio/star/clip_143.wav
# Saved: synthetic_audio/star/clip_144.wav
# Saved: synthetic_audio/star/clip_145.wav
# Saved: synthetic_audio/star/clip_146.wav
# Saved: synthetic_audio/star/clip_147.wav
# Saved: synthetic_audio/star/clip_148.wav
# Saved: synthetic_audio/star/clip_149.wav
# Saved: synthetic_audio/star/clip_150.wav
# Saved: synthetic_audio/star/clip_151.wav
# Saved: synthetic_audio/star/clip_152.wav
# Saved: synthetic_audio/star/clip_153.wav
# Saved: synthetic_audio/star/clip_154.wav
# Saved: synthetic_audio/star/clip_155.wav
# Saved: synthetic_audio/star/clip_156.wav
# Saved: synthetic_audio/star/clip_157.wav
# Saved: synthetic_audio/star/clip_158.wav
# Saved: synthetic_audio/star/clip_159.wav
# Saved: synthetic_audio/star/clip_160.wav
# Saved: synthetic_audio/star/clip_161.wav
# Saved: synthetic_audio/star/clip_162.wav
# Saved: synthetic_audio/star/clip_163.wav
# Saved: synthetic_audio/star/clip_164.wav
# Saved: synthetic_audio/star/clip_165.wav
# Saved: synthetic_audio/star/clip_166.wav
# Saved: synthetic_audio/star/clip_167.wav
# Saved: synthetic_audio/star/clip_168.wav
# Saved: synthetic_audio/star/clip_169.wav
# Saved: synthetic_audio/star/clip_170.wav
# Saved: synthetic_audio/star/clip_171.wav
# Saved: synthetic_audio/star/clip_172.wav
# Saved: synthetic_audio/star/clip_173.wav
# Saved: synthetic_audio/star/clip_174.wav
# Saved: synthetic_audio/star/clip_175.wav
# Saved: synthetic_audio/star/clip_176.wav
# Saved: synthetic_audio/star/clip_177.wav
# Saved: synthetic_audio/star/clip_178.wav
# Saved: synthetic_audio/star/clip_179.wav
# Saved: synthetic_audio/star/clip_180.wav
# Saved: synthetic_audio/star/clip_181.wav
# Saved: synthetic_audio/star/clip_182.wav
# Saved: synthetic_audio/star/clip_183.wav
# Saved: synthetic_audio/star/clip_184.wav
# Saved: synthetic_audio/star/clip_185.wav
# Saved: synthetic_audio/star/clip_186.wav
# Saved: synthetic_audio/star/clip_187.wav
# Saved: synthetic_audio/star/clip_188.wav
# Saved: synthetic_audio/star/clip_189.wav
# Saved: synthetic_audio/star/clip_190.wav
# Saved: synthetic_audio/star/clip_191.wav
# Saved: synthetic_audio/star/clip_192.wav
# Saved: synthetic_audio/star/clip_193.wav
# Saved: synthetic_audio/star/clip_194.wav
# Saved: synthetic_audio/star/clip_195.wav
# Saved: synthetic_audio/star/clip_196.wav
# Saved: synthetic_audio/star/clip_197.wav
# Saved: synthetic_audio/star/clip_198.wav
# Saved: synthetic_audio/star/clip_199.wav
# Saved: synthetic_audio/star/clip_200.wav
# Saved: synthetic_audio/triangle/clip_001.wav
# Saved: synthetic_audio/triangle/clip_002.wav
# Saved: synthetic_audio/triangle/clip_003.wav
# Saved: synthetic_audio/triangle/clip_004.wav
# Saved: synthetic_audio/triangle/clip_005.wav
# Saved: synthetic_audio/triangle/clip_006.wav
# Saved: synthetic_audio/triangle/clip_007.wav
# Saved: synthetic_audio/triangle/clip_008.wav
# Saved: synthetic_audio/triangle/clip_009.wav
# Saved: synthetic_audio/triangle/clip_010.wav
# Saved: synthetic_audio/triangle/clip_011.wav
# Saved: synthetic_audio/triangle/clip_012.wav
# Saved: synthetic_audio/triangle/clip_013.wav
# Saved: synthetic_audio/triangle/clip_014.wav
# Saved: synthetic_audio/triangle/clip_015.wav
# Saved: synthetic_audio/triangle/clip_016.wav
# Saved: synthetic_audio/triangle/clip_017.wav
# Saved: synthetic_audio/triangle/clip_018.wav
# Saved: synthetic_audio/triangle/clip_019.wav
# Saved: synthetic_audio/triangle/clip_020.wav
# Saved: synthetic_audio/triangle/clip_021.wav
# Saved: synthetic_audio/triangle/clip_022.wav
# Saved: synthetic_audio/triangle/clip_023.wav
# Saved: synthetic_audio/triangle/clip_024.wav
# Saved: synthetic_audio/triangle/clip_025.wav
# Saved: synthetic_audio/triangle/clip_026.wav
# Saved: synthetic_audio/triangle/clip_027.wav
# Saved: synthetic_audio/triangle/clip_028.wav
# Saved: synthetic_audio/triangle/clip_029.wav
# Saved: synthetic_audio/triangle/clip_030.wav
# Saved: synthetic_audio/triangle/clip_031.wav
# Saved: synthetic_audio/triangle/clip_032.wav
# Saved: synthetic_audio/triangle/clip_033.wav
# Saved: synthetic_audio/triangle/clip_034.wav
# Saved: synthetic_audio/triangle/clip_035.wav
# Saved: synthetic_audio/triangle/clip_036.wav
# Saved: synthetic_audio/triangle/clip_037.wav
# Saved: synthetic_audio/triangle/clip_163.wav
# Saved: synthetic_audio/triangle/clip_164.wav
# Saved: synthetic_audio/triangle/clip_165.wav
# Saved: synthetic_audio/triangle/clip_166.wav
# Saved: synthetic_audio/triangle/clip_167.wav
# Saved: synthetic_audio/triangle/clip_168.wav
# Saved: synthetic_audio/triangle/clip_169.wav
# Saved: synthetic_audio/triangle/clip_170.wav
# Saved: synthetic_audio/triangle/clip_171.wav
# Saved: synthetic_audio/triangle/clip_172.wav
# Saved: synthetic_audio/triangle/clip_173.wav
# Saved: synthetic_audio/triangle/clip_174.wav
# Saved: synthetic_audio/triangle/clip_175.wav
# Saved: synthetic_audio/triangle/clip_176.wav
# Saved: synthetic_audio/triangle/clip_177.wav
# Saved: synthetic_audio/triangle/clip_178.wav
# Saved: synthetic_audio/triangle/clip_179.wav
# Saved: synthetic_audio/triangle/clip_180.wav
# Saved: synthetic_audio/triangle/clip_181.wav
# Saved: synthetic_audio/triangle/clip_182.wav
# Saved: synthetic_audio/triangle/clip_183.wav
# Saved: synthetic_audio/triangle/clip_184.wav
# Saved: synthetic_audio/triangle/clip_185.wav
# Saved: synthetic_audio/triangle/clip_186.wav
# Saved: synthetic_audio/triangle/clip_187.wav
# Saved: synthetic_audio/triangle/clip_188.wav
# Saved: synthetic_audio/triangle/clip_189.wav
# Saved: synthetic_audio/triangle/clip_190.wav
# Saved: synthetic_audio/triangle/clip_191.wav
# Saved: synthetic_audio/triangle/clip_192.wav
# Saved: synthetic_audio/triangle/clip_193.wav
# Saved: synthetic_audio/triangle/clip_194.wav
# Saved: synthetic_audio/triangle/clip_195.wav
# Saved: synthetic_audio/triangle/clip_196.wav
# Saved: synthetic_audio/triangle/clip_197.wav
# Saved: synthetic_audio/triangle/clip_198.wav
# Saved: synthetic_audio/triangle/clip_199.wav
# Saved: synthetic_audio/triangle/clip_200.wav
# All audio clips generated and saved.

# %% [markdown]
# Generate synthetic audio (Fixed amplitude and noise leve, different frequency classes) - for analysis of message consistency within classes

# %%
import numpy as np
import os
from scipy.signal import square, sawtooth
from scipy.io.wavfile import write

# Constants
sample_rate = 16000
duration = 2  # seconds
num_samples = int(sample_rate * duration)
output_dir = "output_dataset"
classes = ['circle', 'heart', 'hexagon', 'square', 'star', 'triangle']

# Fixed amplitude and noise
FIXED_AMPLITUDE = 0.7
NOISE_LEVEL = 0.02

# Frequency class ranges
frequency_classes = {
    '0': (200, 300),
    '1': (400, 500),
    '2': (600, 800)
}

# --- Waveform Generators (same as before, assuming duration is global) ---

def generate_heart_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    carrier = np.sin(2 * np.pi * freq * t)
    modulator = 0.5 * (1 + np.sin(2 * np.pi * freq / 4 * t))
    return amp * carrier * modulator

def generate_hexagon_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    mod_freq = freq / 2
    mod = np.sin(2 * np.pi * mod_freq * t)
    return amp * np.sin(2 * np.pi * freq * t + mod)

def generate_square_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    return amp * square(2 * np.pi * freq * t)

def generate_star_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    return amp * sawtooth(2 * np.pi * freq * t)

def generate_circle_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    mod_freq = 2
    mod = np.sin(2 * np.pi * mod_freq * t)
    carrier = np.sin(2 * np.pi * freq * (1 + 0.5 * mod) * t)
    return amp * carrier

def generate_triangle_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    stepped_freq = np.piecewise(
        t,
        [t < 0.5, (t >= 0.5) & (t < 1.0), (t >= 1.0) & (t < 1.5), t >= 1.5],
        [freq, freq * 0.75, freq * 0.5, freq * 0.25]
    )
    return amp * np.sin(2 * np.pi * stepped_freq * t)

# Map class names to generator functions
wave_generators = {
    'circle': generate_circle_wave,
    'heart': generate_heart_wave,
    'hexagon': generate_hexagon_wave,
    'square': generate_square_wave,
    'star': generate_star_wave,
    'triangle': generate_triangle_wave
}

# --- Generate and Save Audio Clips ---

for class_name in classes:
    generator = wave_generators[class_name]

    for freq_class_label, (f_min, f_max) in frequency_classes.items():
        freq_dir = os.path.join(output_dir, class_name, freq_class_label)
        os.makedirs(freq_dir, exist_ok=True)

        for i in range(1, 41):
            freq = np.random.uniform(f_min, f_max)

            waveform = generator(freq, FIXED_AMPLITUDE)

            noise = np.random.normal(0, NOISE_LEVEL, num_samples)
            waveform = np.clip(waveform + noise, -1.0, 1.0)

            file_name = f"clip_{i:03d}.wav"
            file_path = os.path.join(freq_dir, file_name)
            write(file_path, sample_rate, (waveform * 32767).astype(np.int16))

        print(f"Saved 200 clips for {class_name} in frequency class {freq_class_label}")

print("All audio clips generated and saved.")
# Out:
# Saved 200 clips for circle in frequency class 0
# Saved 200 clips for circle in frequency class 1
# Saved 200 clips for circle in frequency class 2
# Saved 200 clips for heart in frequency class 0
# Saved 200 clips for heart in frequency class 1
# Saved 200 clips for heart in frequency class 2
# Saved 200 clips for hexagon in frequency class 0
# Saved 200 clips for hexagon in frequency class 1
# Saved 200 clips for hexagon in frequency class 2
# Saved 200 clips for square in frequency class 0
# Saved 200 clips for square in frequency class 1
# Saved 200 clips for square in frequency class 2
# Saved 200 clips for star in frequency class 0
# Saved 200 clips for star in frequency class 1
# Saved 200 clips for star in frequency class 2
# Saved 200 clips for triangle in frequency class 0
# Saved 200 clips for triangle in frequency class 1
# Saved 200 clips for triangle in frequency class 2
# All audio clips generated and saved.

# %% [markdown]
# Generate synthetic audio (Fixed frequency and noise leve, different amplitude classes) - for analysis of message consistency within classes

# %%
import numpy as np
import os
from scipy.signal import square, sawtooth
from scipy.io.wavfile import write

# Constants
sample_rate = 16000
duration = 2  # seconds
num_samples = int(sample_rate * duration)
output_dir = "output_dataset_amplitude"
classes = ['circle', 'heart', 'hexagon', 'square', 'star', 'triangle']

# Fixed frequency
FIXED_FREQUENCY = 440  # Standard A4 note, can be adjusted if needed
NOISE_LEVEL = 0.02

# Amplitude class ranges
amplitude_classes = {
    '0': (0.3, 0.4),
    '1': (0.5, 0.6),
    '2': (0.7, 0.9)
}

# --- Waveform Generators ---

def generate_heart_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    carrier = np.sin(2 * np.pi * freq * t)
    modulator = 0.5 * (1 + np.sin(2 * np.pi * freq / 4 * t))
    return amp * carrier * modulator

def generate_hexagon_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    mod_freq = freq / 2
    mod = np.sin(2 * np.pi * mod_freq * t)
    return amp * np.sin(2 * np.pi * freq * t + mod)

def generate_square_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    return amp * square(2 * np.pi * freq * t)

def generate_star_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    return amp * sawtooth(2 * np.pi * freq * t)

def generate_circle_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    mod_freq = 2
    mod = np.sin(2 * np.pi * mod_freq * t)
    carrier = np.sin(2 * np.pi * freq * (1 + 0.5 * mod) * t)
    return amp * carrier

def generate_triangle_wave(freq, amp):
    t = np.linspace(0, duration, num_samples, endpoint=False)
    stepped_freq = np.piecewise(
        t,
        [t < 0.5, (t >= 0.5) & (t < 1.0), (t >= 1.0) & (t < 1.5), t >= 1.5],
        [freq, freq * 0.75, freq * 0.5, freq * 0.25]
    )
    return amp * np.sin(2 * np.pi * stepped_freq * t)

# Map class names to generator functions
wave_generators = {
    'circle': generate_circle_wave,
    'heart': generate_heart_wave,
    'hexagon': generate_hexagon_wave,
    'square': generate_square_wave,
    'star': generate_star_wave,
    'triangle': generate_triangle_wave
}

# --- Generate and Save Audio Clips ---

for class_name in classes:
    generator = wave_generators[class_name]

    for amp_class_label, (a_min, a_max) in amplitude_classes.items():
        amp_dir = os.path.join(output_dir, class_name, amp_class_label)
        os.makedirs(amp_dir, exist_ok=True)

        for i in range(1, 41):
            amp = np.random.uniform(a_min, a_max)

            waveform = generator(FIXED_FREQUENCY, amp)

            noise = np.random.normal(0, NOISE_LEVEL, num_samples)
            waveform = np.clip(waveform + noise, -1.0, 1.0)

            file_name = f"clip_{i:03d}.wav"
            file_path = os.path.join(amp_dir, file_name)
            write(file_path, sample_rate, (waveform * 32767).astype(np.int16))

        print(f"Saved 40 clips for {class_name} in amplitude class {amp_class_label}")

print("All audio clips generated and saved.")
# Out:
# Saved 40 clips for circle in amplitude class 0
# Saved 40 clips for circle in amplitude class 1
# Saved 40 clips for circle in amplitude class 2
# Saved 40 clips for heart in amplitude class 0
# Saved 40 clips for heart in amplitude class 1
# Saved 40 clips for heart in amplitude class 2
# Saved 40 clips for hexagon in amplitude class 0
# Saved 40 clips for hexagon in amplitude class 1
# Saved 40 clips for hexagon in amplitude class 2
# Saved 40 clips for square in amplitude class 0
# Saved 40 clips for square in amplitude class 1
# Saved 40 clips for square in amplitude class 2
# Saved 40 clips for star in amplitude class 0
# Saved 40 clips for star in amplitude class 1
# Saved 40 clips for star in amplitude class 2
# Saved 40 clips for triangle in amplitude class 0
# Saved 40 clips for triangle in amplitude class 1
# Saved 40 clips for triangle in amplitude class 2
# All audio clips generated and saved.
